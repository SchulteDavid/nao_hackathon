# %% [markdown]
# # Linienerkennung
# Damit sich ein Roboter auf den Spielfeld lokalisieren kann muss er der Feldlinien erkennen. Dafür nimmt er mit seinen beiden Kameras Bilder auf und wendet darauf einen Algorithmus an, der die Feldlinien erkennt.
#
# In dieser Challange sollst du selber so ein Algorithmus schreiben. Dafür bekommst du eine Klasse `FieldLineAnalyser` die du benutzen kannst. Diese Klasse hat eine Methode `calc_metrics_for_all_images` die du implementieren sollst. Diese Methode bekommt eine Funktion übergeben, die ein Bild bekommt und eine Liste von Feldlinien zurückgibt. Die Feldlinien sind als Liste von Punkten kodiert. Jeder Punkt ist ein String der die x und y Koordinate des Punktes enthält. Die Koordinaten sind durch ein Komma getrennt. Die Punkte sind durch ein Semikolon getrennt.

# %%
# ein paar Beispielfotos
from IPython.display import Image
Image(filename='../images/field_lines/RC2022_4th-Game-vsBHuman-G1A_CometInterceptor_PLAY_00222518__U.png')

# %%
Image(filename='../images/field_lines/GO2018G4B_Gargamel_00123134_L.png')

# %%
import naobackend.analysis.field_line_analyser as fla
# Out:
# ['/mnt/notebooks/Advanced', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/jupyter-env/lib/python3.10/site-packages']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 print(sys.path)
# ----> 3 import naobackend.analysis.field_line_analyser as fla
#
# File /jupyter-env/lib/python3.10/site-packages/naobackend/analysis/field_line_analyser.py:7
#       5 import matplotlib.pyplot as plt
#       6 import numpy as np
# ----> 7 import shapely
#       8 from shapely.ops import unary_union
#       9 from shapely.geometry import LineString
#
# ModuleNotFoundError: No module named 'shapely'

# %%
analyser = fla.FieldLineAnalyser()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 analyser = fla.FieldLineAnalyser()
#
# NameError: name 'fla' is not defined

# %% [markdown]
# In die folgenden Funktion kannst du dein Algorithmus schreiben. Viel Spaß!

# %%
def analyze(image):
    return [
        {"points": "0,0;0,100;100,100;100,0;0,0"},
        {"points": "0,0;0,100;100,100;100,0;0,0"}
    ]

# %% [markdown]
# Der Moment der Wahrheit. Jetzt rufen wir dein Algorithmus auf diversen gelabelten Testdaten auf. Als Scores haben wir neben Presicion, Recall, iou (Ist ein array mit einem Wert für jedes Bild) und F1. Der wichtigste Scoure ist der F1 Score dieser ist (mit beta 0.5) etwas mehr auf precision gewichtet. Unser bestes Modell hat ein F1 Score von 0.61 erreicht. Wir sind gespannt ob du das toppen kannst.

# %%
precision, recall, iou, f1 = analyser.calc_metrics_for_all_images(analyze)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 precision, recall, iou, f1 = analyser.calc_metrics_for_all_images(analyze)
#
# NameError: name 'analyser' is not defined

# %%
# print precision, recall and f1
print("precision: ", precision)
print("recall: ", recall)
print("f1: ", f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # print precision, recall and f1
# ----> 2 print("precision: ", precision)
#       3 print("recall: ", recall)
#       4 print("f1: ", f1)
#
# NameError: name 'precision' is not defined
